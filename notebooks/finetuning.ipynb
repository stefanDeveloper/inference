# %%
# !nvidia-smi
# Out:
# Tue Mar 16 14:23:53 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/stefanDeveloper/inference.git
# Out:
# Cloning into 'inference'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 92 (delta 43), reused 66 (delta 22), pack-reused 0
# Unpacking objects: 100% (92/92), done.

# %%
# %cd inference
# Out:
# /content/inference

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 22.3MB 1.5MB/s
# ...
#      |████████████████████████████████| 1.9MB 57.4MB/s
# ...
#      |████████████████████████████████| 3.2MB 50.3MB/s
# ...
#      |████████████████████████████████| 890kB 46.3MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=31bb6b79f462a25183a8b33daafae299491eb9c03707fd5f73186b087f5b21d0
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !python -m sarn.train --max-checkpoints 1 --train-batch-size 10 --test-batch-size 10 --output-dir "models/deberta" --log-dir "logs/deberta" "microsoft/deberta-large-mnli" "data/training.csv"
# Out:
# 2021-03-16 14:25:27.932929: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Loading model microsoft/deberta-large-mnli
# Downloading: 100% 729/729 [00:00<00:00, 686kB/s]
# Downloading: 100% 1.62G/1.62G [00:44<00:00, 36.4MB/s]
# Some weights of the model checkpoint at microsoft/deberta-large-mnli were not used when initializing DebertaForSequenceClassification: ['config']
# - This IS expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# !zip -r result.zip models/ logs/
# !cp result.zip /content/gdrive/MyDrive/Semantik/deberta.zip
# Out:
#   adding: models/ (stored 0%)
#   adding: models/deberta/ (stored 0%)
#   adding: models/deberta/checkpoint-9500/ (stored 0%)
#   adding: models/deberta/checkpoint-9500/bpe_encoder.bin (deflated 58%)
#   adding: models/deberta/checkpoint-9500/tokenizer_config.json (deflated 37%)
#   adding: models/deberta/checkpoint-9500/special_tokens_map.json (deflated 40%)
#   adding: models/deberta/checkpoint-9500/optimizer.pt (deflated 17%)
#   adding: models/deberta/checkpoint-9500/scheduler.pt (deflated 49%)
#   adding: models/deberta/checkpoint-9500/pytorch_model.bin (deflated 7%)
#   adding: models/deberta/checkpoint-9500/trainer_state.json (deflated 86%)
#   adding: models/deberta/checkpoint-9500/training_args.bin (deflated 45%)
#   adding: models/deberta/checkpoint-9500/config.json (deflated 51%)
#   adding: models/deberta/bpe_encoder.bin (deflated 58%)
#   adding: models/deberta/tokenizer_config.json (deflated 37%)
#   adding: models/deberta/special_tokens_map.json (deflated 40%)
# ...
